# %%
import json
test_path = "../data/AWS_SAM_split/test.json"

with open(test_path, 'r') as f:
    test_data = json.load(f)

print(test_data.keys())
# Out:
# dict_keys(['info', 'images', 'annotations', 'categories'])

# %%
print(len(test_data['images']))
test_data['images'][0]
# Out:
# 468
# {'id': 1, 'file_name': '02521.png', 'height': 960, 'width': 1280}

# %%
print(len(test_data['annotations']))
test_data['annotations'][0]
# Out:
# {'id': 1,
#  'image_id': 1,
#  'category_id': 96,
#  'bbox': [1.7524752475247567,
#   591.0891089108911,
#   901.9801980198018,
#   80.1980198019802],
#  'area': 18394.275071071308,
#  'iscrowd': 0,
#  'segmentation': [[1.7524752475247567,
#    633.6633663366337,
#    2.742574257425744,
#    610.8910891089109,
#    132.44554455445544,
#    631.6831683168317,
#    322.54455445544556,
#    647.5247524752475,
#    464.1287128712871,
#    649.5049504950495,
#    591.8514851485148,
#    641.5841584158416,
#    708.6831683168317,
#    625.7425742574258,
#    782.940594059406,
#    613.8613861386139,
#    797.7920792079208,
#    607.9207920792079,
#    813.6336633663366,
#    608.9108910891089,
#    879.9702970297029,
#    591.0891089108911,
#    889.8712871287129,
#    595.049504950495,
#    903.7326732673266,
#    597.0297029702971,
#    846.3069306930693,
#    617.8217821782179,
#    833.4356435643564,
#    617.8217821782179,
#    813.6336633663366,
#    625.7425742574258,
#    791.8514851485148,
#    626.7326732673267,
#    753.2376237623762,
#    637.6237623762377,
#    747.2970297029702,
#    629.7029702970297,
#    737.3960396039604,
#    632.6732673267327,
#    737.3960396039604,
#    642.5742574257425,
#    693.8316831683168,
#    648.5148514851485,
#    696.8019801980198,
#    639.6039603960396,
#    683.9306930693069,
#    635.6435643564356,
#    677.0,
#    651.4851485148515,
#    581.950495049505,
#    664.3564356435644,
#    557.1980198019802,
#    663.3663366336633,
#    537.3960396039604,
#    669.3069306930693,
#    329.4752475247525,
#    671.2871287128713,
#    321.55445544554453,
#    654.4554455445544,
#    311.65346534653463,
#    653.4653465346535,
#    307.6930693069307,
#    671.2871287128713,
#    162.14851485148517,
#    658.4158415841584,
#    166.10891089108912,
#    640.5940594059406,
#    160.16831683168317,
#    635.6435643564356,
#    143.33663366336634,
#    656.4356435643564]]}
